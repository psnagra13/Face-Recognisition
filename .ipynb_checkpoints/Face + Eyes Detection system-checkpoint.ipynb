# %% [markdown]
# # Face + Eyes Detection System

# %% [markdown]
# ### Importing required Libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
import glob
import cv2
# %matplotlib inline

# %% [markdown]
# ### Reading images

# %%
def read_image (path):
    image = cv2.imread(path,cv2.IMREAD_COLOR)
    image_copy = image.copy()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # Convert image to grayscale
    return image, image_copy

# %% [markdown]
# ### Load face and eyes Cascade Classifier

# %%
facecascade = cv2.CascadeClassifier('data/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('data/haarcascade_eye.xml')

# %%
def face_detection(image):
    faces = facecascade.detectMultiScale(image, scaleFactor=1.2, minNeighbors=5)
    return faces

# %%
def eyes_detection(image):
    eyes = eye_cascade.detectMultiScale(image)
    return eyes

# %%
def detect_face(image_path):
    image, image_copy = read_image(image_path)    
    faces = face_detection(image)    
    print("Total number of Faces found",len(faces))  
    for (x, y, w, h) in faces:
        face_detect = cv2.rectangle(image, (x, y), (x+w, y+h), (100, 100, 100), 4)
        plt.imshow(face_detect)
        face_image = image[y:y+h, x:x+w]
        eyes = eyes_detection(face_image)

        for (ex,ey,ew,eh) in eyes:
            eye_detect = cv2.rectangle(image,(ex+x,ey+y),(ex+ew+x,ey+eh+y),(255,0,255),2)
            plt.imshow(eye_detect)

# %%
path = 'data/images/test1.jpg'
detect_face(path)
# Out:
# Total number of Faces found 12

# %%
path = 'data/images/test2.jpg'
detect_face(path)
# Out:
# Total number of Faces found 1

# %%
path = 'data/images/test3.jpg'
detect_face(path)
# Out:
# Total number of Faces found 8

# %%
path = 'data/images/test4.jpg'
detect_face(path)
# Out:
# Total number of Faces found 16

# %%
path = 'data/images/test7.jpg'
detect_face(path)
# Out:
# Total number of Faces found 1
